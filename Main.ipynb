# %%
import pandas as pd
import numpy as np

# %%
RANDOM_STATE = 42
shipping = pd.read_csv('Data/shipping.csv')

# %%
shipping.head()
# Out:
#                    id    type         parent                name  dob age  \
# 0  vtls004589021_0_13  sailor  vtls004589021  william cunningham  blk  19
# 1  vtls004589021_0_14  sailor  vtls004589021      evan griffiths  blk  21
# 2  vtls004589021_0_12  sailor  vtls004589021         henry evans  blk  27
# 3  vtls004589069_0_14  sailor  vtls004589069         david evans  blk  16
# 4  vtls004589021_1_13  sailor  vtls004589021       richard jones  blk  20
#
#   place_of_birth home_address    f name_of_ship    ship_port date_leaving  \
# 0      liverpool          blk  blk       adroit  aberystwyth      1873-12
# 1      portmadoc          blk  blk   jane owens   porthmadoc      1874-04
# 2    aberystwyth          blk  blk       adroit  aberystwyth      1873-12
# 3      aberaeron          blk  blk       adroit  aberystwyth      remains
# 4    aberystwyth          blk  blk       adroit  aberystwyth      1874-06
#
# ...
